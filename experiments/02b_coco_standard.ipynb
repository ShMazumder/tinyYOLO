# %% [markdown]
# # 02b: COCO Standard
# Baseline benchmark for Table 3. Run all cells. Results save to `experiments/results/`.

# %%
import os, sys, socket
try:
    socket.create_connection(("github.com", 80), timeout=5)
except:
    print("❌ ERROR: No Internet connection. If on Kaggle, toggle 'Internet' to ON in the sidebar settings.")
    sys.exit(1)

# !rm -rf tinyYOLO && git clone https://github.com/ShMazumder/tinyYOLO.git
# %cd tinyYOLO
# !pip install -e . -q
# !pip install tqdm timm -q
# !python3 -c "from ultralytics.data.utils import check_det_dataset; check_det_dataset('coco.yaml')"

# %%
# !python3 scripts/train.py --task det --variant standard --data coco.yaml \
    --imgsz 416 --epochs 150 --batch 128 --seed 42 --warmup 3 \
    --pretrained --compile --name coco-s-416-seed42

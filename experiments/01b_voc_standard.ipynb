# %% [markdown]
# # 01b: VOC Standard (5 Seeds)
# Baseline benchmark for Table 1. Run all cells. Results save to `experiments/results/`.

# %%
# !rm -rf tinyYOLO && git clone https://github.com/ShMazumder/tinyYOLO.git
# %cd tinyYOLO
# !pip install -e . -q
# !pip install tqdm timm -q
# !python3 -c "from ultralytics.data.utils import check_det_dataset; check_det_dataset('VOC.yaml')"

# %%
SEEDS = [42, 123, 256, 512, 1024]
for s in SEEDS:
    # !python3 scripts/train.py --task det --variant standard --data voc.yaml \
        --imgsz 416 --epochs 150 --batch 128 --seed {s} --warmup 3 \
        --pretrained --compile --name voc-s-416-seed{s}
